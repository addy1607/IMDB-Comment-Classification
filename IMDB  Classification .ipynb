# %%
import pandas as pd

messages = pd.read_csv("imdb_categories_1.csv")

# %%
messages
# Out:
#                                                  comment     CategoryName
# 0      When a woman reads out some cards to name the ...     Sex & Nudity
# 1      The President "Snowballs" says that everyone w...     Sex & Nudity
# 2      In one of the help canisters that is recieved ...     Sex & Nudity
# 3      There are also a number of other crude jokes m...     Sex & Nudity
# 4      Son of a bitch is used twice (one is heard off...        Profanity
# ...                                                  ...              ...
# 35385  An infected man leaps at Abi, but the army man...  Violence & Gore
# 35386  Abi, Ashley and an army man enter a room and s...  Violence & Gore
# 35387  An infected man leaps at the army man holding ...  Violence & Gore
# 35388  We see a dead woman on a operating table, and ...  Violence & Gore
# 35389  Abi is seen running, and another mysterious cr...  Violence & Gore
#
# [35390 rows x 2 columns]

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adityagupta/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['comment'][i])
    review = review.lower()
    review = review.split()
    
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    
    review = ' '.join(review)
    corpus.append(review)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 corpus = []
# ----> 2 for i in range(0, len(messages)):
#       3     review = re.sub('[^a-zA-Z]', ' ', messages['comment'][i])
#       4     review = review.lower()
#
# NameError: name 'messages' is not defined

# %%
corpus
# Out:
# ['woman read card name tribut follow name come meant context huge anu feel hooter',
#  'presid snowbal say everyon want see lesbian love stori group colleg girl appear arena danc eroticli nippl grow larg',
#  'one help canist reciev long collect multi colour condom',
#  'also number crude joke made throughout movi',
#  'son bitch use twice one heard offscreen five use shit ass use twice',
#  'basi film cal wife emili slept anoth man want divorc',
#  'sexual content film made dialogu impli instanc actual scene one liner doubl entendr crude humor fill script male genitalia refer cal constantli talk wife screw anoth man refer pole danc oral sex one joke talk minut porno video made',
#  'cal hook differ women divorc although see one affair one kate see passion kiss caress writh around cal apart dark realist yet somewhat comic kate push cal onto sofa stand tabl shake backsid spread leg jump scene cut nuditi',
# ...

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500)
X = cv.fit_transform(corpus).toarray()

# %%
#Data preprocessing
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
messages["CategoryName"]=label_encoder.fit_transform(messages["CategoryName"])

# %%
messages.head()
# Out:
#                                              comment  CategoryName
# 0  When a woman reads out some cards to name the ...             3
# 1  The President "Snowballs" says that everyone w...             3
# 2  In one of the help canisters that is recieved ...             3
# 3  There are also a number of other crude jokes m...             3
# 4  Son of a bitch is used twice (one is heard off...             2

# %%
messages["CategoryName"].unique()
# Out:
# array([3, 2, 0, 1, 4])

# %%
y=messages["CategoryName"]

# %%
# Train Test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.naive_bayes import MultinomialNB
detect_model = MultinomialNB().fit(X_train, y_train)

# %%
#prediction
y_pred=detect_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.8937552981068099

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       648
#            1       0.69      0.78      0.73       902
#            2       0.87      0.97      0.92       673
#            3       0.92      0.93      0.93      1787
#            4       0.94      0.87      0.91      3068
#
#     accuracy                           0.89      7078
#    macro avg       0.87      0.90      0.89      7078
# weighted avg       0.90      0.89      0.89      7078

# %%
# Creating the TFIDF model
from sklearn.feature_extraction.text import TfidfVectorizer
tv = TfidfVectorizer(max_features=2500)
X = tv.fit_transform(corpus).toarray()

# %%
# Train Test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.naive_bayes import MultinomialNB
detect_model = MultinomialNB().fit(X_train, y_train)

# %%
#prediction
y_pred=detect_model.predict(X_test)

# %%
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.8937552981068099

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       648
#            1       0.69      0.78      0.73       902
#            2       0.87      0.97      0.92       673
#            3       0.92      0.93      0.93      1787
#            4       0.94      0.87      0.91      3068
#
#     accuracy                           0.89      7078
#    macro avg       0.87      0.90      0.89      7078
# weighted avg       0.90      0.89      0.89      7078
